# %% [markdown]
# ### Задание 1
#
# Напишите программу, вычисляющую площадь треугольника по переданным длинам трёх его сторон по формуле Герона:
# $$ S = \sqrt{p(p-a)(p-b)(p-c)}, $$
# где $p=\frac{a+b+c}{2}$ - полупериметр треугольника.
#
# На вход программе подаются целые числа, выводом программы должно являться вещественное число, соответствующее площади треугольника.
#
# Пример ввода/вывода
# ```py
# Sample Input:
# 3
# 4
# 5
# Sample Output:
# 6.0
# ```

# %%
a=int(input('введите а'))
if a==0:
   print('ошибка a=0')
b=int(input('введите b'))
if b==0:
   print('ошибка b=0')
c= int(input('введите  с'))
if c==0:
   print('ошибка c=0')
if a>0 and b>0 and c>0:
   p=((a+b+c)/2)
   s=(((p)*(p-a)*(p-b)*(p-c))**0.5)
   print('площадь треугольника:')
   print(s)
# Out:
# ошибка a=0
# ошибка b=0
# ошибка c=0

# %% [markdown]
# ### Задание 2
#
# Напишите программу, принимающую на вход целое число, которая выводит `True`, если переданное значение попадает в интервал
# $$\left(−15,12\right]∪(14,17)∪[19,+∞) $$
#  и `False` в противном случае (регистр символов имеет значение).
#
# Обратите внимание на разные скобки, используемые для обозначения интервалов. В задании используются полуоткрытые и открытые интервалы.

# %%
a= int(input('введите число'))
print('ваше число:')
print(a)
if (-15<a<=12) or (14<a>17) or (19<=a):
    print (True)
else:
    print(False)
# Out:
# ваше число:
# 14
# False

# %% [markdown]
# ### Задание 3
# Напишите простой калькулятор, который считывает с пользовательского ввода три строки: первое число, второе число и операцию, после чего применяет операцию к введённым числам ("первое число" "операция" "второе число") и выводит результат на экран.
# Поддерживаемые операции: `+`, `-`, `/`, `*`, `mod`, `pow`, `div`, где
#  - `mod` — это взятие остатка от деления,
#  - `pow` — возведение в степень,
#  - `div` — целочисленное деление.
#
# Если выполняется деление и второе число равно 0, необходимо выводить строку `"Деление на 0!"`.
# Обратите внимание, что на вход программе приходят вещественные числа.
#
# Пример ввода/вывода
# ```py
# Sample Input 1:
# 5.0
# 0.0
# mod
# Sample Output 1:
# Деление на 0!
#
# Sample Input 2:
# -12.0
# -8.0
# *
# Sample Output 2:
# 96.0
# ```

# %%
deystvie =  ['+','-','/','*','mod-взятие остатка от деления','pow-возведение в степень ','div-целочисленное деление']
for i, deystvie in enumerate(deystvie, start=1):
    print(i,deystvie)
deystvie=int(input('выберите действие'))
if deystvie>=8:
    print('ответ:')
    print('ошибка действие не выбранно')
else:
    a=int(input('введите число a'))
    b=int(input('введите число b'))
if deystvie==1:
    c=a+b
    print ('ответ:')
    print (c)
elif deystvie==2:
    c=a-b
    print ('ответ:')
    print (c)
elif deystvie==3:
    if b==0:
        print('ответ:')
        print('ошибка')
    else:
        c=a/b
        print ('ответ:')
        print (c)
elif deystvie==4:
    c=a*b
    print ('ответ:')
    print (c)
elif deystvie==5:
    c=a%b
    print ('ответ:')
    print (c)
elif deystvie==6:
    c=a**b
    print ('ответ:')
    print (c)
elif deystvie==7:
    c=a//b
    print ('ответ:')
    print (c)
# Out:
# 1 +
# 2 -
# 3 /
# 4 *
# 5 mod-взятие остатка от деления
# 6 pow-возведение в степень
# 7 div-целочисленное деление
# ответ:
# ошибка

# %% [markdown]
# ### Задание 4
#
# Жители страны Малевии часто экспериментируют с планировкой комнат. Комнаты бывают треугольные, прямоугольные и круглые. Чтобы быстро вычислять жилплощадь, требуется написать программу, на вход которой подаётся тип фигуры комнаты и соответствующие параметры, которая бы выводила площадь получившейся комнаты.
# Для числа $\pi$ в стране Малевии используют значение 3.14.
#
# Формат ввода, который используют Малевийцы:
# ```py
# треугольник
# a
# b
# c
# ```
# где a, b и c — длины сторон треугольника
# ```py
# прямоугольник
# a
# b
# ```
# где a и b — длины сторон прямоугольника
# ```py
# круг
# r
# ```
# где r — радиус окружности

# %%
figura=['треугольная комната','прямоугольна комната','круглая комната']
for i, figura in enumerate(figura,start=1):
    print(i,figura)
figura=int(input('выберите комнату'))
if figura>=3:
    print('ответ:')
    print('выбор возможен из 3 видов')
elif figura==1:
    print('вы выбрали треугольник, введите его стороны')
    a=int(input('введите число a'))
    b=int(input('введите число b'))
    c=int(input('введите число c'))
    if a==0 or b==0 or c ==0:
        print('ответ:')
        print('ошибка  сторона не может быть равна 0')
    else:
        p=(a+b+c)/2
        s=(p*(p-a)*(p-b)*(p-c))**0.5
        print('ответ:')
        print(s)
elif figura==2:
    print('вы выбрали прямоугольник, введите его стороны')
    if a==0 or b ==0:
       print('ответ:')
       print('ошибка  сторона не может быть равна 0')
    else:
       a=int(input('введите a'))
       b=int(input('введите b'))
       s=a*b
       print('ответ:')
       print(s)
elif figura==3:
    print('вы выбрали круг, введите его радиус')
    a=int(input('введите радиус'))
    if a==0:
        print('ответ:')
        print('ошибка радиус не может быть равна 0')
    else:
        b=3.14
        s=((a)**2)*b
        print('ответ:')
        print(s)
# Out:
# 1 треугольная комната
# 2 прямоугольна комната
# 3 круглая комната
# вы выбрали треугольник, введите его стороны
# ответ:
# 111.80339887498948

# %% [markdown]
# ### Задание 5
#
# Напишите программу, которая получает на вход три целых числа, по одному числу в строке, и выводит на консоль в три строки сначала максимальное, потом минимальное, после чего оставшееся число.
#
# На ввод могут подаваться и повторяющиеся числа.
#
# Пример работы
# ```py
# Sample Input 1:
# 8
# 2
# 14
# Sample Output 1:
# 14
# 2
# 8
#
# Sample Input 2:
# 23
# 23
# 21
# Sample Output 2:
# 23
# 21
# 23
# ```

# %%
number=[a,b,c]
a=int(input('введите число а'))
b=int(input('введите число b'))
c=int(input('введите число с'))
if a==b or b==c or a==c:
    print('ошибка два числа из трёх равны')
else:
    sorted_nums=sorted([a,b,c])
    min=sorted_nums[0]
    middle=sorted_nums[1]
    maxim=sorted_nums[2]
    print('ответ:')
    print('минимальное число')
    print(min)
    print('среднее число')
    print(middle)
    print('максимальное число')
    print(maxim)
    print('вы ввели числа:')
    print(a,b,c)
# Out:
# ответ:
# минимальное число
# 14
# среднее число
# 15
# максимальное число
# 500
# вы ввели числа:
# 14 500 15

# %% [markdown]
# ### Задание 6
# Для определения числа студентов, присутствующих на занятии, разработана программа, которая в заданное считает количество отметившихся в первые 15 минут занятия в LMS Moodle и произносит вслух: "На паре присутствует n студентов".
#
# Для того, чтобы это звучало правильно, для каждого n нужно использовать верное окончание слова.
#
# Напишите программу, считывающую с пользовательского ввода целое число n (неотрицательное), выводящее это число в консоль вместе с правильным образом изменённым словом "студент", чтобы программа могла корректно озвучивать численность присутствующих: 1 студент, 2 студента, 5 студентов.
#
# В аудитории может быть очень много студентов. Проверьте, что ваша программа правильно обработает все случаи, как минимум до 100 человек.
#
# Пример работы
# ```py
# Sample Input 1:
# 5
# Sample Output 1:
# 5 студентов
#
# Sample Input 2:
# 0
# Sample Output 2:
# 0 студентов
# ```

# %%
a=float(input('введите колличество студентов'))
max_limit=100
min_limit=0
if a==1:
    print('1 студент')
elif a>1:
    print(a,'студентов')
elif a==0:
    print(a,'студентов')
elif a<0:
    print('ошибка')
# Out:
# 10.0 студентов

# %% [markdown]
# ### Задание 7
# Проверьте, является ли билет на общественном транспорте, счастливым или нет. Билет считается счастливым, если сумма первых трех цифр совпадает с суммой последних трех цифр номера билета.
#
# Напишите программу, которая проверит равенство сумм и выведет "Счастливый", если суммы совпадают, и "Обычный", если суммы различны.
#
# На вход программе подаётся строка из шести цифр.
# Выводить нужно только слово "Счастливый" или "Обычный", с большой буквы.
#
# Пример работы
# ```py
# Sample Input 1:
# 090234
# Sample Output 1:
# Счастливый
#
# Sample Input 2:
# 123456
# Sample Output 2:
# Обычный
# ```

# %%
a = input('введите номер билета')
s1 = int(a[0]) + int(a[1]) + int(a[2])
s2 = int(a[3]) + int(a[4]) + int(a[5])
if s1 == s2:
    print('Счастливый')
else:
    print('Обычный')
# Out:
# Счастливый

# %% [markdown]
# ### Задание 8
# Напишите программу, которая считывает с консоли числа (по одному в строке) до тех пор, пока сумма введённых чисел не будет равна 0 и сразу после этого выводит сумму квадратов всех считанных чисел.
#
# Гарантируется, что в какой-то момент сумма введённых чисел окажется равной 0, после этого считывание продолжать не нужно.
#
# В примере мы считываем числа 1, -3, 5, -6, -10, 13; в этот момент замечаем, что сумма этих чисел равна нулю и выводим сумму их квадратов, не обращая внимания на то, что остались ещё не прочитанные значения.
#
# Пример работы
# ```py
# Sample Input:
# 1
# -3
# 5
# -6
# -10
# 13
# 4
# -8
# Sample Output:
# 340
# ```

# %%
numbers=[a]
a=int(input('введите числа'))
#while sum[a]>=0:
    #print(sum([a]**2))
#else:
    #print('сумма введённых числе не равна 0')
    #print([numbers])

# %% [markdown]
# ### Задание 9
# Выведите таблицу размером $n \times n$, заполненную числами от $1$ до $n^2$ по спирали, выходящей из левого верхнего угла и закрученной по часовой стрелке, как показано в примере (здесь $n = 5$).
#
# Пример работы
# ```py
# Sample Input:
# 5
# Sample Output:
# 1 2 3 4 5
# 16 17 18 19 6
# 15 24 25 20 7
# 14 23 22 21 8
# 13 12 11 10 9
# ```

# %%
n=int(input('введите n'))
def spiral_matrix(n):  
    matrix=[[0]*n for _ in range(n)]
    top,bottom=0,n-1
    left,right=0,n-1
    num=1
    while top <=bottom and left<=right:
        for col in range(left,right+1):
            matrix[top][col]=num
            num+=1
        top+=1
        for row in range(top,bottom+1):
            matrix [row][right]=num
            num+=1
        right-=1
        if top<=bottom:
            for col in range(right,left -1,-1):
                matrix[bottom][col]=num
                num+=1
            bottom-=1
        if left<=right:
            for row in range (bottom,top-1,-1):
                matrix[row][left]=num
                num+=1
            left+=1
    return matrix
def print_matrix(matrix):
    for row in matrix:
        print(''.join(map(str,row)))
result=spiral_matrix(n)
print_matrix(result)
# Out:
# 12345
# 161718196
# 152425207
# 142322218
# 131211109

# %% [markdown]
# ### Задание 10
# Напишите программу, которая вычисляет сумму последовательностей из двоек до указанной пользователем длины $n$. Например, при $n=5$ получим $$2 + 22 + 222 + 2222 + 22222 = 24690.$$
#
# Пример работы
# ```py
# Sample Input:
# 5
# Sample Output:
# 24690
# ```
